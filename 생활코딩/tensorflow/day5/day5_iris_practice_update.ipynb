# %%
import tensorflow as tf
import pandas as pd

# %%
# 데이터 호출\
filename = "iris.csv"
data_raw = pd.read_csv(filename)

# 범주형 데이터이기 때문에 원핫 인코딩으로 진행 --> 각 종속 변수를 분리하여 0, 1로 분류
data = pd.get_dummies(data_raw)

# 범주의 분류 구하기
# data_raw['품종'].value_counts()

# %%
# 데이터 세팅
# iloc 와 미묘한 차이가 있다
iv = data[['꽃잎길이', '꽃잎폭', '꽃받침길이', '꽃받침폭']]
dv = data[['품종_setosa', '품종_versicolor', '품종_virginica']]

# %%
# 비율 예측을 위해 활성화함수 softmax 사용
#  0 <= softmax() <= 1
X = tf.keras.layers.Input(shape=[4]) # 4개의 input

# hidden layer 추가
H = tf.keras.layers.Dense(8, activation="swish")(X)
H = tf.keras.layers.Dense(8, activation="swish")(H)
H = tf.keras.layers.Dense(8, activation="swish")(H)

Y = tf.keras.layers.Dense(3, activation="softmax")(H) # 3개의 범주
model = tf.keras.models.Model(X, Y)
model.compile(loss="categorical_crossentropy", metrics='accuracy')

# %%
model.fit(iv, dv, epochs=10000, verbose=0)
model.fit(iv, dv, epochs=10)
# Out:
# Epoch 1/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0393 - accuracy: 0.9867
# Epoch 2/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0376 - accuracy: 0.9800
# Epoch 3/10
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0396 - accuracy: 0.9800
# Epoch 4/10
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0345 - accuracy: 0.9867
# Epoch 5/10
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0392 - accuracy: 0.9867
# Epoch 6/10
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0377 - accuracy: 0.9800
# Epoch 7/10
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0372 - accuracy: 0.9867
# Epoch 8/10
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0344 - accuracy: 0.9867
# Epoch 9/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0355 - accuracy: 0.9933
# Epoch 10/10
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0367 - accuracy: 0.9800

# %%
print(model.predict(iv[:5]))
print(dv[:5])
# Out:
# [[1.0000000e+00 1.0090965e-09 0.0000000e+00]
#  [1.0000000e+00 1.0912698e-10 0.0000000e+00]
#  [1.0000000e+00 6.1680361e-10 3.0098386e-38]
#  [1.0000000e+00 6.7045275e-10 4.8272647e-37]
#  [1.0000000e+00 3.9822865e-09 0.0000000e+00]]
#    품종_setosa  품종_versicolor  품종_virginica
# 0          1              0             0
# 1          1              0             0
# 2          1              0             0
# 3          1              0             0
# 4          1              0             0

# %%
# 모델의 가중치 확인
model.get_weights()
# Out:
# [array([[-0.33153394,  0.855035  ,  0.5284237 , -0.1302876 ,  0.336131  ,
#          -0.31537363,  0.08174673,  0.2424683 ],
#         [-0.17024192,  0.43322232,  0.54378176, -0.17503195, -0.66509837,
#           0.6367806 , -0.4589806 ,  0.36759955],
#         [ 1.0362544 , -0.17194067, -0.5967825 , -0.15487297,  0.5043281 ,
#          -0.30259016, -0.373885  ,  0.19447707],
#         [ 0.5820652 , -1.0156561 , -0.68861496, -0.59519047,  1.0008191 ,
#          -0.9802461 , -0.41277727,  0.7173562 ]], dtype=float32),
#  array([-0.18070608,  0.37839583,  0.4318429 ,  0.51822275, -0.5728705 ,
#          0.5475475 ,  0.5212719 , -0.70213956], dtype=float32),
#  array([[-1.0392116 , -0.5026315 ,  0.75665903, -0.8611477 , -0.2932031 ,
#          -0.11139487, -0.6760767 ,  0.11422287],
#         [ 0.31221193,  0.33138406, -0.38476974,  0.38924608,  0.27112824,
#          -0.8315502 ,  0.46161503, -0.19894639],
#         [ 1.1689904 ,  0.56319743, -1.4933003 ,  0.9588696 ,  0.2564915 ,
#          -0.8757693 , -0.03700118, -0.46076766],
#         [-0.8481856 , -1.454178  , -1.4756953 , -0.7116506 ,  1.0020741 ,
#          -0.4167948 ,  1.2125194 ,  1.4763674 ],
#         [-0.20020062, -0.6671681 , -0.62178856,  0.05343696,  0.59845597,
#           0.76574564,  0.360189  ,  0.6538097 ],
#         [-1.2431561 , -1.0285935 , -1.2424928 , -0.97928685,  1.2666601 ,
#           0.5267076 ,  0.9067913 ,  0.8233293 ],
#         [-1.1083877 , -1.2552725 , -1.5758404 , -1.0711199 ,  1.549542  ,
#          -0.53067166,  1.3667204 ,  1.1687859 ],
#         [ 0.32276747, -0.25638965, -0.26553306, -0.29495376, -0.08361591,
#           0.22689277,  0.6724269 ,  0.27362376]], dtype=float32),
#  array([ 0.2676452 ,  0.46937868,  0.23622979,  0.36098576, -0.43691996,
#          0.09620211, -0.22910023, -0.4291281 ], dtype=float32),
#  array([[ 0.4384114 ,  0.02238506,  1.7764004 ,  0.4396103 , -1.1393698 ,
#           0.9706981 , -2.217846  ,  0.77853155],
#         [ 1.9425981 , -1.2542883 , -0.4081425 ,  1.2769871 , -0.95337945,
#          -0.6151197 ,  0.9177928 ,  0.3615329 ],
#         [ 0.81513923, -0.6695102 , -1.194083  ,  0.9611206 , -1.2047988 ,
#          -0.47582284, -0.5557263 ,  1.2303315 ],
#         [-0.7768746 ,  0.8179002 ,  2.4720604 , -0.7915043 ,  0.53574145,
#           1.3332859 , -1.9368196 , -0.5668337 ],
#         [-0.02878879, -0.24753278,  0.28783253,  0.7457039 , -0.7756766 ,
#           0.07865064, -2.850437  ,  0.5524681 ],
#         [ 1.6018785 , -0.4300339 ,  0.02823903,  0.44408563,  0.09894249,
#          -0.19159345,  7.42202   ,  1.0143894 ],
#         [ 0.3915785 ,  0.47975618, -0.02080815,  0.20013963, -0.7228546 ,
#          -0.01301846, -1.2188658 ,  0.48158127],
#         [ 0.24472651, -0.710555  , -0.41230363,  0.53897655, -0.18575563,
#          -0.24163301, -1.1521473 ,  0.29806542]], dtype=float32),
#  array([-0.16352998,  0.35690913,  0.21017836, -0.2842574 ,  0.45457765,
#          0.49487785,  0.25934586, -0.4135765 ], dtype=float32),
#  array([[ 5.515632  , -1.6928718 ,  0.95560294],
#         [-6.354541  ,  0.80024034, -0.59949774],
#         [ 2.3324466 ,  0.8963382 , -1.7223449 ],
#         [-3.698209  , -0.37498635,  1.2599134 ],
#         [ 3.23505   , -0.7339895 ,  1.4533244 ],
#         [ 0.90235245,  1.1673006 , -1.1853435 ],
#         [-1.2386992 ,  6.0352187 , -2.257628  ],
#         [-7.7967243 , -0.21742947,  0.42404976]], dtype=float32),
#  array([-6.6225543 ,  0.34408748, -0.3337895 ], dtype=float32)]
